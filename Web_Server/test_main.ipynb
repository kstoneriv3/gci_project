# %%
import pandas as pd
import numpy as np

import predictor
import convert_raw_data
import convert_to_json
import get_info
import data_box


analytical_data = data_box.analytical_data
raw_data = data_box.raw_data
info = get_info.get_info("https://chintai.mynavi.jp/tokyo/113/room121700007311.html")
data = info[1].to_frame().T
name = info[0]
# Out:
# C:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\base.py:311: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.19.0 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# C:\Program Files (x86)\Anaconda3\lib\site-packages\sklearn\base.py:311: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 0.19.0 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
name
# Out:
# 'パインフラット\u30004階'

# %%
data_cnv = convert_raw_data.get_AnalyticalData(data)

# %%
predictor.get_pred(data_cnv)
# Out:
# 8.7839999999999971

# %%
text_to_render = convert_to_json.convert_to_json(data_cnv,predictor.get_pred)
# Out:
# C:\Users\Kei\Desktop\GCI\gci_project\Web_Server\convert_to_json.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_new["予測価格"] = y_pred_regional
# C:\Users\Kei\Desktop\GCI\gci_project\Web_Server\convert_to_json.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_new["割引率(％)"] = round((1-regional_data.rent/y_pred_regional)*1000)/10
# C:\Users\Kei\Desktop\GCI\gci_project\Web_Server\convert_to_json.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
print(text_to_render)
# Out:
# [
# {"URL":"https://chintai.mynavi.jp/tokyo/112/room9400008933.html","価格(家賃)":"5.55","床面積":"20.53","緯度":"35.6555979","経度":"139.6102864","築年":"1992.0","予測価格":"6.443500000000001","割引率(％)":"13.9","最寄駅":"千歳烏山駅","最寄駅への所要時間":"16","間取り":"1DK","方角":"南","コンロ口数":"2.0","浴室乾燥機":"浴室乾燥機なし","オートロック":"オートロックなし","フローリング":"フローリング〇","選択物件":"周囲の物件 (500m県内) "},
# {"URL":"https://chintai.mynavi.jp/tokyo/112/room2102800000355.html","価格(家賃)":"5.5","床面積":"24.32","緯度":"35.6555979","経度":"139.6102864","築年":"1991.0","予測価格":"6.707500000000002","割引率(％)":"18.0","最寄駅":"祖師ケ谷大蔵駅","最寄駅への所要時間":"17","間取り":"1K","方角":"方角不明","コンロ口数":"1.0","浴室乾燥機":"浴室乾燥機なし","オートロック":"オートロックなし","フローリング":"フローリング〇","選択物件":"周囲の物件 (500m県内) "},
# ...

# %%
import numbers
def is_numeric(n):
    return isinstance(n, numbers.Number) or (type(n)==np.bool_) or (type(n)=='bool') or (type(n)==np.int64)

# %%
data_cnv.T[data_cnv.iloc[0,:].apply(is_numeric)==False].index
# Out:
# Index(['url'], dtype='object')

# %%
# Converter に足りてないカラム名
data.columns[pd.Series(data.columns).apply(lambda x:x not in list(analytical_data.columns))]
# Out:
# Index([], dtype='object')

# %%
# Converter に入った余計なカラム名
analytical_data.columns[pd.Series(analytical_data.columns).apply(lambda x:x not in list(data.columns))]
# Out:
# Index([], dtype='object')

# %%
data_cnv.iloc[:,105:110]
# Out:
#    buildings_undergrand_Null_to_Zero  total_units_Null_to_Zero  \
# 0                                  0                         1
#
#    balcony_Null_to_Zero  shower_Null_to_Zero  bath_drier_Null_to_Zero
# 0                     0                    1                        0
